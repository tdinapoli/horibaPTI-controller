# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
#plt.style.use('seaborn')
mpl.rcParams['figure.dpi'] = 100
mpl.rcParams['legend.fontsize'] = 15
mpl.rcParams['axes.labelsize'] = 15
mpl.rcParams['xtick.labelsize'] = 10
mpl.rcParams['ytick.labelsize'] = 10

# %%
df = pd.read_pickle("/home/tomi/Documents/facultad/tesis/git/data/oscuridad_total/data.pickle")
df = df.transpose()
df.head()
# Out:
#                                                0.001  \
# 0  [-0.55421615, 2.214423, -2.7808466, -4.4581437...
# 1  [-2.9737236, 2.5000763, 5.3346353, 2.238838, 6...
# 2  [5.27604, 5.271157, 5.2833643, 5.2833643, 5.29...
# 3  [-0.82033753, 6.523637, 1.7261269, -6.328318, ...
# 4  [5.312662, 5.312662, 5.288247, 5.302896, 5.293...
#
#                                                0.012  \
# 0  [-1.1963255, 0.4809717, 5.4054384, 6.657918, 4...
# 1  [-5.6617937, 5.561693, -4.250618, -1.9849238, ...
# 2  [-0.32959992, 4.919584, -1.3452559, -3.0079043...
# 3  [-4.038209, 1.7188025, 6.7873163, 2.7588732, -...
# 4  [5.312662, 5.271157, 5.312662, 5.2735987, 5.29...
#
#                                                0.023  \
# 0  [-2.5000763, 0.78127384, 1.5625477, 2.1387372,...
# 1  [-0.63722646, 4.792627, 1.2500381, 3.2447278, ...
# 2  [-4.4874415, 5.7814264, 5.6300545, -0.0634785,...
# 3  [-3.3985412, 0.76418346, 1.8140202, -1.1645863...
# ...

# %%
x = np.arange(0, len(df[0.001][5]))
d = df[0.001][5]
plt.plot(x,-d )
plt.xlim([12750, 13750])
plt.show()

# %%
xs, hs = sp.signal.find_peaks(-d, height=(-4.5, 10))
hs = -hs["peak_heights"]
plt.plot(x, d)
plt.plot(xs, hs, 'o', color="orange")
plt.show()

# %%
bins = np.linspace(-10, 10, 50)
freq, bin_edges = np.histogram(d, bins=bins)
plt.stairs(freq, bin_edges, fill=True)
plt.yscale("log")
plt.show()

# %%
wls = np.arange(500, 740, 1)
espectro = []
for i, wl in enumerate(wls):
    cuentas = np.load(f"/home/tomi/Documents/facultad/tesis/git/data/europio/2023-10-11/1.0_vueltas_0.1_int/{wl}.npy")
    xs, hs = sp.signal.find_peaks(-cuentas, height=(-3.7, 1))
    peaks = -hs["peak_heights"]
    espectro.append(len(peaks))
    t = np.arange(len(cuentas))
    if wl == 615:
        xs2 = xs[300]
        plt.plot(t[xs2-10:xs2+10], cuentas[xs2-10:xs2+10])
        #plt.plot(xs, peaks, 'o')
        plt.show()

# %%
xs2 = xs[1]
plt.plot(t[xs2-10:xs2+10], cuentas[xs2-10:xs2+10])

plt.show()

# %%
plt.plot(wls, espectro, '.-')
plt.show()

# %% [markdown]
# Posiblemente sea el 1er armónico de la excitación a 290 (la rendija de excitacioń estaba abierta distinta)

# %% [markdown]
# comparando con el espectro sacado por el software original:
# ![Alt text](image.png)

# %%
# %matplotlib widget

# %%
screen = np.load("/home/tomi/Documents/facultad/tesis/git/data/20-10-2023/osc_screens_photon_width/0200.npy")
plt.figure()
plt.plot(np.arange(len(screen)), screen)
#plt.xlim([2380, 2430])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
screen = np.load("/home/tomi/Documents/facultad/tesis/git/data/20-10-2023/osc_screens_photon_width/0300.npy")
plt.figure()
plt.plot(np.arange(len(screen)), screen)
#plt.xlim([2380, 2430])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
