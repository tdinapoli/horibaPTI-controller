# %%
# %matplotlib widget
from ucnpexp.gui import SpectrometerGUI
gui = SpectrometerGUI()
gui.create_gui()
# Out:
# interactive(children=(Dropdown(description='Spectrum type:', options=('Emission', 'Excitation'), style=Descrip…
# <function ucnpexp.gui.SpectrometerGUI.display_spectrum_widgets.<locals>._display_spectrum_widgets(type)>
# interactive(children=(Dropdown(description='measurement_name', options=(), style=DescriptionStyle(description_…
# FileChooser(path='/home/tomi/HORIBA/measurements', filename='', title='Measurement name:', show_hidden=False, …
# Button(description='Measure', style=ButtonStyle())
# <function ucnpexp.gui.SpectrometerGUI.update_plot.<locals>._update_plot(measurement_name)>
# Dropdown(description='File format:', options=('Excel', 'csv', 'pickle'), style=DescriptionStyle(description_wi…
# Button(description='Save measurement', style=ButtonStyle())
# interactive(children=(Button(description='Run Interact', style=ButtonStyle()), Output()), _dom_classes=('widge…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
